# %% [markdown]
# ## Importing the required libraries for Model Development

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline     
sns.set(color_codes=True)

#modeling

from xgboost import XGBRegressor 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score, train_test_split, KFold, StratifiedGroupKFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
from sklearn import ensemble
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7b3bfca91be5> in <module>
#      12 from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV
#      13 from sklearn.svm import SVR
# ---> 14 from sklearn.model_selection import cross_val_score, train_test_split, KFold, StratifiedGroupKFold, GridSearchCV
#      15 from sklearn.metrics import mean_squared_error, r2_score
#      16 from sklearn.preprocessing import StandardScaler, MinMaxScaler
#
# ImportError: cannot import name 'StratifiedGroupKFold' from 'sklearn.model_selection' (/global/software/sl-7.x86_64/modules/langs/python/3.7/lib/python3.7/site-packages/sklearn/model_selection/__init__.py)

# %% [markdown]
# ## Loading the data from Google Drive

# %% [markdown]
# ❗**NOTE: Before running this step, add a shortcut of the shared project folder to your drive**:
# https://drive.google.com/drive/folders/1Zss_aak84cHnoGLaK6lUQLyDNKqAdn6s?usp=sharing

# %%
data_path = 'global/home/users/yaqiantang/discoveryData' + \
 'data_monthly_v1_0.csv'
df = pd.read_csv(data_path)

# %%
df.head(5)
# Out:
#   SITE_ID  year  month  TIMESTAMP  dataset SITE_IGBP  LOCATION_LAT  \
# 0  AR-SLu  2010      1     201001  FLUXNET        MF      -33.4648
# 1  AR-SLu  2010      2     201002  FLUXNET        MF      -33.4648
# 2  AR-SLu  2010      3     201003  FLUXNET        MF      -33.4648
# 3  AR-SLu  2010      4     201004  FLUXNET        MF      -33.4648
# 4  AR-SLu  2010      5     201005  FLUXNET        MF      -33.4648
#
#    LOCATION_LONG    TA_F   VPD_F  ...  Percent_Snow  Fpar  Lai  LST_Day  \
# 0       -66.4598  28.493  23.378  ...           0.0  0.49  1.2   313.84
# 1       -66.4598  26.673  14.369  ...           0.0  0.43  0.9   309.86
# 2       -66.4598  25.744  15.167  ...           0.0  0.41  0.8   309.18
# 3       -66.4598  18.450   9.185  ...           0.0  0.36  0.5   303.24
# 4       -66.4598  13.493   5.823  ...           0.0  0.37  0.5   296.20
#
#    LST_Night  MODIS_IGBP  MODIS_PFT  koppen_sub  koppen  CO2_concentration
# 0     293.58         OSH         SH         BSk    Arid            387.110
# 1     292.96         OSH         SH         BSk    Arid            387.675
# 2     290.52         OSH         SH         BSk    Arid            388.195
# 3     286.34         OSH         SH         BSk    Arid            388.905
# 4     277.82         OSH         SH         BSk    Arid            389.320
#
# [5 rows x 62 columns]

# %%
df.tail(5)
# Out:
#       SITE_ID  year  month  TIMESTAMP   dataset SITE_IGBP  LOCATION_LAT  \
# 19010  SE-Lnn  2018      8     201808  ICOS2018       CRO      58.34063
# 19011  SE-Lnn  2018      9     201809  ICOS2018       CRO      58.34063
# 19012  SE-Lnn  2018     10     201810  ICOS2018       CRO      58.34063
# 19013  SE-Lnn  2018     11     201811  ICOS2018       CRO      58.34063
# 19014  SE-Lnn  2018     12     201812  ICOS2018       CRO      58.34063
#
#        LOCATION_LONG    TA_F  VPD_F  ...  Percent_Snow  Fpar  Lai  LST_Day  \
# 19010       13.10177  16.767  5.483  ...      0.000000  0.28  0.5   296.66
# 19011       13.10177  11.719  2.344  ...      0.000000  0.43  0.7   290.18
# 19012       13.10177   7.827  1.575  ...      0.000000  0.54  1.0   284.16
# 19013       13.10177   3.794  0.563  ...      0.800000   NaN  NaN   277.06
# 19014       13.10177   1.015  0.418  ...     14.666666   NaN  NaN   271.54
#
#        LST_Night  MODIS_IGBP  MODIS_PFT  koppen_sub  koppen  CO2_concentration
# 19010     282.84         CRO        CRO         Dfb    Cold            406.525
# 19011     280.78         CRO        CRO         Dfb    Cold            405.985
# 19012     276.10         CRO        CRO         Dfb    Cold            406.280
# 19013     270.88         CRO        CRO         Dfb    Cold            407.320
# 19014     267.06         CRO        CRO         Dfb    Cold            407.820
#
# [5 rows x 62 columns]

# %%
df.describe()
# Out:
#                year         month      TIMESTAMP  LOCATION_LAT  LOCATION_LONG  \
# count  19015.000000  19015.000000   19015.000000  19015.000000   19015.000000
# mean    2010.626821      6.590849  201069.272942     42.190960     -21.169896
# std        5.150904      3.387905     515.043678     18.723591      68.771907
# min     2001.000000      1.000000  200101.000000    -37.425900    -157.408900
# 25%     2006.000000      4.000000  200612.000000     39.942690     -90.079900
# 50%     2011.000000      7.000000  201103.000000     45.945900       5.743560
# 75%     2015.000000     10.000000  201502.000000     50.893060      13.512590
# max     2020.000000     12.000000  202012.000000     78.186000     161.341430
#
#                TA_F         VPD_F           P_F        NETRAD   NEE_VUT_REF  \
# count  19015.000000  19015.000000  18662.000000  16322.000000  19015.000000
# mean      10.335353      5.431886      2.095369     81.498813     -0.636588
# std        9.497750      5.196374      2.008792     60.609140      2.119773
# min      -31.455000      0.007000      0.000000    -67.894013    -14.029700
# 25%        3.874000      1.884000      0.727000     25.832575     -1.494660
# 50%       10.966000      4.008000      1.619000     83.546492     -0.034683
# 75%       17.159000      6.997500      2.871000    131.353100      0.638339
# max       33.400000     45.384000     25.172000    307.991579      8.817250
#
#        ...          NDVI          NDWI          NIRv         kNDVI  \
# count  ...  18563.000000  18609.000000  18563.000000  18609.000000
# mean   ...      0.535087      0.165757      0.131622      0.305653
# std    ...      0.200831      0.199895      0.072160      0.173797
# min    ...      0.002544     -0.276199      0.001238      0.000016
# 25%    ...      0.405351      0.028162      0.076971      0.165432
# 50%    ...      0.570044      0.169703      0.116626      0.315323
# 75%    ...      0.691212      0.283465      0.175177      0.444393
# max    ...      0.915832      0.854756      0.426510      0.685111
#
#        Percent_Snow          Fpar           Lai       LST_Day     LST_Night  \
# count  18872.000000  18080.000000  18080.000000  19015.000000  19015.000000
# mean      11.620639      0.484481      1.430520    289.817007    277.196492
# std       26.684868      0.199732      1.128479     13.737654      9.700046
# min        0.000000      0.060000      0.100000    238.540000    237.900000
# 25%        0.000000      0.330000      0.500000    280.380000    271.240000
# 50%        0.000000      0.500000      1.100000    290.900000    277.920000
# 75%        1.171358      0.650000      2.100000    298.460000    284.180000
# max      100.000000      0.910000      6.300000    328.280000    299.340000
#
#        CO2_concentration
# count       19015.000000
# mean          390.256548
# std            11.250848
# min           369.070000
# 25%           381.500000
# 50%           389.320000
# 75%           398.230000
# max           413.325000
#
# [8 rows x 54 columns]

# %% [markdown]
# ## Understand the data variables

# %% [markdown]
# GPP: Gross primary productivity.
#
# Here the dataset includes monthly GPP in unit of gram carbon per m2 per day (gC m-2 d-1)
#
# The GPP data is in a column named 'GPP_NT_VUT_REF'.

# %%
# attributes of eddy covariance site
site_data_attrs = ['SITE_ID','dataset','LOCATION_LAT','LOCATION_LONG','SITE_IGBP','MODIS_PFT','koppen']

# target variable: GPP
target = 'GPP_NT_VUT_REF'

# %% [markdown]
# Below is a list of explanatory variables that will be used in the ML models. These data were collected from satellite images, gridded climate datasets, and other geospatial datasets. A description of these variable is provided here:
# https://docs.google.com/document/d/1uwn2okcE5IB5x4fDELnF2qRizDwLH9H_EfLFHqg_eRo/edit?usp=sharing
#
# Feel free to Google if any of these terms don't sound familiar to you.

# %%
# explanatory variables
exp_vars = [
    'BESS-PAR',  
    'BESS-PARdiff', 
    'BESS-RSDN', 
    'Tmean', 
    'prcp', 
    'vpd', 
    'prcp-lag3',
    'ESACCI-sm', 
    'ET', 
    'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI', 'NIRv', 'kNDVI', 
    'CSIF-SIFdaily', 
    'Fpar', 'Lai', 
    'LST_Day', 'LST_Night', 
    'MODIS_PFT', 
    'koppen', 
]

# %%
df[exp_vars].dtypes
# Out:
# BESS-PAR           int64
# BESS-PARdiff       int64
# BESS-RSDN          int64
# Tmean            float64
# prcp             float64
# vpd              float64
# prcp-lag3        float64
# ESACCI-sm        float64
# ET               float64
# b1               float64
# b2               float64
# b3               float64
# b4               float64
# b5               float64
# b6               float64
# b7               float64
# EVI              float64
# NDVI             float64
# GCI              float64
# NDWI             float64
# NIRv             float64
# kNDVI            float64
# CSIF-SIFdaily    float64
# Fpar             float64
# Lai              float64
# LST_Day          float64
# LST_Night        float64
# MODIS_PFT         object
# koppen            object
# dtype: object

# %% [markdown]
# ## One Hot Encoding of Categorical Variables
# * MODIS_PFD
# * koppen

# %%
# keep columns needed for stratified KFold
df_ohe = df[[target, 'MODIS_IGBP', 'SITE_ID'] + exp_vars]

categorical_columns = ['MODIS_PFT', 'koppen']
for col in categorical_columns:
    col_ohe = pd.get_dummies(df[col], prefix=col)
    df_ohe = pd.concat((df_ohe, col_ohe), axis=1).drop(col, axis=1)

df_ohe.columns
# Out:
# Index(['GPP_NT_VUT_REF', 'MODIS_IGBP', 'SITE_ID', 'BESS-PAR', 'BESS-PARdiff',
#        'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
#        'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
#        'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
#        'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
#        'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
#        'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
#        'koppen_Temperate', 'koppen_Tropical'],
#       dtype='object')

# %% [markdown]
# ## Training and Testing Data

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    return df

# %%
# clean the data.
df = clean_dataset(df_ohe)

# %%
# Function to standardize variables and create test/train split 
def get_train_test_split(df, test_size, random_state, neural_net=False):
    """
    This function returns four dataframes containing the testing and training X and y values.
    Input:
        df: df that contains the target/response variable and all the features.
        y_col: a column name (as a string) of df that represents the response variable
        test_size: a float between 0 and 1 indicating the fraction of the data to include in the test split
        random_state: an integer, used to define the random state,
        neural_net: boolean if making split for neural network model to determine how we should standardize 
    Output: X_train, X_test, y_train, y_test, four dataframes containing the training and testing subsets of the 
    feature matrix X and response matrix y
    """
    
    X = df[['BESS-PAR', 'BESS-PARdiff',
       'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
       'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
       'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
       'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
       'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
       'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
       'koppen_Temperate', 'koppen_Tropical']]
    y = df[target]
    
    # Standardize the data
    if not neural_net:
      scaler = StandardScaler()
      scaler.fit(X) 
      X_stnd = scaler.transform(X)
    else:
      scaler = MinMaxScaler(feature_range=(0, 1))
      X_stnd = scaler.fit_transform(X)
    
    X_train, X_test, y_train, y_test = train_test_split(X_stnd, y, test_size=test_size, random_state=random_state, shuffle=True)
    
    return X_train, X_test, y_train, y_test, scaler

# %%
X_train, X_test, y_train, y_test, scaler = get_train_test_split(df, 0.3, 2022)

# %%
X_train
# Out:
# array([[-0.78535436, -0.83276638, -1.03156579, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [ 0.05790123,  0.64407837,  0.23863279, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [ 0.27284873,  0.28484586,  0.67002099, ..., -0.09974929,
#          1.65010801, -0.17707977],
#        ...,
#        [ 1.06650104,  0.20501641,  1.86832154, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [ 0.28938315,  0.48441947,  0.64605498, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [-0.40506262, -0.47353388, -0.43241551, ..., -0.09974929,
#         -0.60602094, -0.17707977]])

# %%
X_test
# Out:
# array([[-1.08297398, -1.03234   , -1.48692   , ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [ 1.01689777,  0.04535752,  2.03608362, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [-1.00030186, -0.95251055, -1.36708994, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        ...,
#        [-0.90109532, -0.83276638, -1.22329387, ..., -0.09974929,
#          1.65010801, -0.17707977],
#        [ 0.37205527, -0.07438665,  0.82580006, ..., -0.09974929,
#         -0.60602094, -0.17707977],
#        [-0.07437416,  0.04535752,  0.05888771, ..., -0.09974929,
#          1.65010801, -0.17707977]])

# %%
y_train
# Out:
# 7303      2.907370
# 13401    11.236600
# 996       7.242190
# 8947      1.256740
# 18339     2.251480
#            ...
# 17269     0.351449
# 6028      6.695440
# 258       1.085580
# 1556      3.463550
# 6347      0.898686
# Name: GPP_NT_VUT_REF, Length: 10728, dtype: float64

# %%
y_test
# Out:
# 12221    1.931420
# 8749     1.617070
# 4388     0.126817
# 11582   -0.118314
# 10833    4.922390
#            ...
# 12005    0.827507
# 6498    -0.049592
# 6072     0.993647
# 1310     9.251160
# 3119     2.353920
# Name: GPP_NT_VUT_REF, Length: 4599, dtype: float64

# %% [markdown]
# ## Model Developoment
# Models:
# * Lasso
# * SVM
# * Random Forest
# * XGBoost
# * Multi-Layer Neural Network
# * LSTM

# %% [markdown]
# ### Lasso

# %%
n_fold = 5
stratify_class = df['MODIS_IGBP'] 
group_kfold = StratifiedGroupKFold(n_splits=n_fold, shuffle=True, random_state=2022)
kf = group_kfold.get_n_splits(X_train, stratify_class, df['SITE_ID'])

lasso_model = LassoCV(cv = kf, alphas=np.linspace(0.001, 10, 100), max_iter = 10000)
lasso_model.fit(X_train, y_train)
print('Lasso Model Optimal Alpha: ', lasso_model.alpha_)
# Out:
# Lasso Model Optimal Alpha:  0.001

# %% [markdown]
# ### Evaluation of Lasso

# %%
def calculate_errors(y_train, y_train_predicted, y_test, y_test_predicted, model_name):
  r2 = r2_score(y_test, y_test_predicted)
  rmse_train = np.sqrt(mean_squared_error(y_train, y_train_predicted))
  rmse_test = np.sqrt(mean_squared_error(y_test, y_test_predicted))
  bias_train = np.mean(y_train - y_train_predicted)
  bias_test = np.mean(y_test - y_test_predicted)
  print("The R2 score of " + model_name + " is: " + str(r2))
  print("The RMSE of predicting the TRAINING set of " + model_name + " is: " + str(rmse_train))
  print("The RMSE of predicting the TESTING set of " + model_name + " is: " + str(rmse_test))
  print("The bias of predicting the TRAINING set of " + model_name + " is: " + str(bias_train))
  print("The bias of predicting the TESTING set of " + model_name + " is: " + str(bias_test))

# %%
def show_scatter_train(y_train, y_train_predicted, model_name):
  plt.figure(figsize=(8,5))
  plt.scatter(x = y_train, y = y_train_predicted)
  plt.plot(y_train, y_train, color = 'red', label = 'x=y')
  plt.title(model_name + " : observed vs. predicted for TRAIN set")
  plt.xlabel('y_train_Observed')
  plt.ylabel('y_train_Predicted');

# %%
def show_scatter_test(y_test, y_test_predicted, model_name):
  plt.figure(figsize=(8,5))
  plt.scatter(x = y_test, y = y_test_predicted)
  plt.plot(y_test, y_test, color = 'red', label = 'x=y')
  plt.title(model_name + " : observed vs. predicted for TEST set")
  plt.xlabel('y_test_Observed')
  plt.ylabel('y_test_Predicted');

# %%
lasso_y_train_predicted = lasso_model.predict(X_train)
lasso_y_test_predicted = lasso_model.predict(X_test)
calculate_errors(y_train, lasso_y_train_predicted, y_test, lasso_y_test_predicted, "Lasso")
# Out:
# The R2 score of Lasso is: 0.7172704219756341
# The RMSE of predicting the TRAINING set of Lasso is: 2.0395830745832786
# The RMSE of predicting the TESTING set of Lasso is: 2.0609264910387615
# The bias of predicting the TRAINING set of Lasso is: -2.980464495638004e-18
# The bias of predicting the TESTING set of Lasso is: -0.01507554441872364

# %%
show_scatter_train(y_train, lasso_y_train_predicted, "Lasso")

# %%
show_scatter_test(y_test, lasso_y_test_predicted, "Lasso")

# %% [markdown]
# Residual Plot for Test Data

# %%
sns.residplot(y_train, lasso_y_train_predicted)
plt.title('Lasso Residual Plot: Training Data')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Lasso Residual Plot: Training Data')

# %%
sns.residplot(y_test, lasso_y_test_predicted)
plt.title('Lasso Residual Plot: Test Data')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Lasso Residual Plot: Test Data')

# %% [markdown]
# Both the training and test residual plots are very similar and show a pattern, but it's not extremely obvious. With an R^2 score of 0.7172704219756341, the lasso model is an OK fit for the data.

# %% [markdown]
# ### SVM

# %%
# defining parameter range
svm_param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001],
              'kernel': ['rbf']} 
  
svm = SVR()
svm_random = RandomizedSearchCV(estimator = svm, param_distributions = svm_param_grid, 
                                scoring='neg_mean_squared_error', n_iter = 10, cv = kf, verbose=2, 
                                random_state=2022, n_jobs = -1)
# Fit the random search model
svm_random.fit(X_train, y_train)
# Print best parameters after tuning
print('SVM Best Parameters: ', svm_random.best_params_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# SVM Best Parameters:  {'kernel': 'rbf', 'gamma': 0.1, 'C': 10}

# %% [markdown]
# ### Evaluation of SVM

# %%
# Model with Cross Validated Hyperparameters
svm_model = SVR(kernel = 'rbf', gamma = 0.1, C = 10)
svm_model.fit(X_train, y_train)

# %%
# Cross Validation Results

rmse = cross_val_score(svm_model, X_train, y_train, scoring='neg_root_mean_squared_error', cv = kf)
r2 = cross_val_score(svm_model, X_train, y_train, scoring='r2', cv = kf)

#get the mean of each fold 
print("RMSE: %.3f, Standard Deviation : %.3f" % (rmse.mean() * -1, rmse.std())) 
print("R2: %.3f, Standard Deviation : %.3f" % (r2.mean(), r2.std()))
# Out:
# RMSE: 1.701, Standard Deviation : 0.036
# R2: 0.810, Standard Deviation : 0.009

# %%
# Train/Test Results
svm_y_train_predicted = svm_model.predict(X_train)
svm_y_test_predicted = svm_model.predict(X_test)
calculate_errors(y_train, svm_y_train_predicted, y_test, svm_y_test_predicted, "SVM")
# Out:
# The R2 score of SVM is: 0.7948418790808225
# The RMSE of predicting the TRAINING set of SVM is: 1.3210237297469607
# The RMSE of predicting the TESTING set of SVM is: 1.7555824694024678
# The bias of predicting the TRAINING set of SVM is: 0.028917121627708417
# The bias of predicting the TESTING set of SVM is: 0.04162584937101107

# %%
show_scatter_train(y_train, svm_y_train_predicted, "SVM")

# %%
show_scatter_test(y_test, svm_y_test_predicted, "SVM")

# %% [markdown]
# Residual Plots for SVM

# %%
sns.residplot(y_train, svm_y_train_predicted)
plt.title('SVM Residual Plot: Training Data')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'SVM Residual Plot: Training Data')

# %%
sns.residplot(y_test, svm_y_test_predicted)
plt.title('SVM Residual Plot: Testing Data')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'SVM Residual Plot: Testing Data')

# %% [markdown]
# The residual plot looks better when the SVM model compared to Lasso. In both, there are a few outliers, but it seems like a pretty good fit overall.

# %% [markdown]
# ### Random Forest

# %%
# Number of trees in random forest
n_estimators = [25, 50, 75, 100, 150, 200]
# Number of features to consider at every split
max_features = ['auto', 'sqrt', 0.1, 0.5, 1.0]
# Maximum number of levels in tree
max_depth = [3, 4, 5, 6]
# Minimum number of samples required to split a node
min_samples_split = [2,3,4,5,6]
# Minimum number of samples required at each leaf node
min_samples_leaf = [2,3,4,5,6]
# Method of selecting samples for training each tree
bootstrap = [True, False]


# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

rf = RandomForestRegressor()
# Random search of parameters, using 5 fold cross validation, search across 10 different combinations
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, 
                               scoring='neg_mean_squared_error',n_iter = 10, cv = kf, verbose=2, 
                               random_state=2022, n_jobs = -1)
# Fit the random search model
rf_random.fit(X_train, y_train)
# Print best parameters after tuning
print('Random Forest Best Parameters: ')
rf_random.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Random Forest Best Parameters:
# {'n_estimators': 200,
#  'min_samples_split': 6,
#  'min_samples_leaf': 6,
#  'max_features': 0.5,
#  'max_depth': 6,
#  'bootstrap': True}

# %% [markdown]
# ### Evaluation of Random Forest

# %%
rf_model = RandomForestRegressor(n_estimators=200, min_samples_split=6, min_samples_leaf=6, 
                                 max_features=0.5, max_depth = 6, bootstrap = False)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=6, max_features=0.5,
#                       min_samples_leaf=6, min_samples_split=6,
#                       n_estimators=200)

# %%
# Cross Validation Results

rmse = cross_val_score(rf_model, X_train, y_train, scoring='neg_root_mean_squared_error', cv = kf)
r2 = cross_val_score(rf_model, X_train, y_train, scoring='r2', cv = kf)

#get the mean of each fold 
print("RMSE: %.3f, Standard Deviation : %.3f" % (rmse.mean() * -1, rmse.std())) 
print("R2: %.3f, Standard Deviation : %.3f" % (r2.mean(), r2.std()))
# Out:
# RMSE: 1.955, Standard Deviation : 0.051
# R2: 0.749, Standard Deviation : 0.007

# %%
# Train/Test Results

rf_y_train_predicted = rf_model.predict(X_train)
rf_y_test_predicted = rf_model.predict(X_test)
calculate_errors(y_train, rf_y_train_predicted, y_test, rf_y_test_predicted, "Random Forest")
# Out:
# The R2 score of Random Forest is: 0.7465317487410839
# The RMSE of predicting the TRAINING set of Random Forest is: 1.81505407577418
# The RMSE of predicting the TESTING set of Random Forest is: 1.9513656842940659
# The bias of predicting the TRAINING set of Random Forest is: -2.0532088747728473e-17
# The bias of predicting the TESTING set of Random Forest is: -0.0031401992904670057

# %%
show_scatter_train(y_train, rf_y_train_predicted, "Random Forest")

# %%
show_scatter_test(y_test, rf_y_test_predicted, "Random Forest")

# %% [markdown]
# Residual Plots for the Random Forest Training Data

# %%
sns.residplot(y_train, rf_y_train_predicted)
plt.title('Random Forest Residual Plot: Training Data');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Random Forest Residual Plot: Training Data')

# %%
sns.residplot(y_test, rf_y_train_predicted)
plt.title('Random Forest Residual Plot: Test Data')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-79c64fd92c15> in <module>
# ----> 1 sns.residplot(y_test, rf_y_train_predicted)
#       2 plt.title('Random Forest Residual Plot: Test Data')
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in residplot(x, y, data, lowess, x_partial, y_partial, order, robust, dropna, label, color, scatter_kws, line_kws, ax)
#    1097                                  order=order, robust=robust,
#    1098                                  x_partial=x_partial, y_partial=y_partial,
# -> 1099                                  dropna=dropna, color=color, label=label)
#    1100
#    1101     if ax is None:
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in __init__(self, x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, color, label)
#     112         # Drop null observations
#     113         if dropna:
# --> 114             self.dropna("x", "y", "units", "x_partial", "y_partial")
#     115
#     116         # Regress nuisance variables out of the data
#
# /usr/local/lib/python3.7/dist-packages/seaborn/regression.py in dropna(self, *vars)
#      60         vals = [getattr(self, var) for var in vars]
#      61         vals = [v for v in vals if v is not None]
# ---> 62         not_na = np.all(np.column_stack([pd.notnull(v) for v in vals]), axis=1)
#      63         for var in vars:
#      64             val = getattr(self, var)
#
# <__array_function__ internals> in column_stack(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/lib/shape_base.py in column_stack(tup)
#     654             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     655         arrays.append(arr)
# --> 656     return _nx.concatenate(arrays, 1)
#     657
#     658
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input array dimensions for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 4599 and the array at index 1 has size 10728

# %% [markdown]
# ### XGBoost

# %%
xgb_param_grid = { 'max_depth': [3, 5, 6, 10], 
                  'min_child_weight': [1, 3, 5, 7],
                  'learning_rate': [0.01, 0.1, 0.2, 0.3],
                  'subsample': np.arange(0.5, 1.0, 0.1),
                  'colsample_bytree': np.arange(0.4, 1.0, 0.1),
                  'colsample_bylevel': np.arange(0.4, 1.0, 0.1),
                  'n_estimators': [50, 100, 150, 200, 250]}

xgbr = XGBRegressor()
xgb_random = RandomizedSearchCV(estimator=xgbr, param_distributions=xgb_param_grid, 
                                scoring='neg_mean_squared_error', n_iter=10, cv = kf, verbose=2, 
                                random_state=2022, n_jobs = -1)
xgb_random.fit(X_train, y_train)
print("XGBoost Best Parameters: ")
xgb_random.best_params_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [23:28:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBoost Best Parameters:
# {'subsample': 0.7999999999999999,
#  'n_estimators': 150,
#  'min_child_weight': 7,
#  'max_depth': 6,
#  'learning_rate': 0.1,
#  'colsample_bytree': 0.8999999999999999,
#  'colsample_bylevel': 0.7}

# %% [markdown]
# ### Evaluation of XGBoost

# %%
xgb_model = XGBRegressor(subsample = 0.8, n_estimators = 150, max_depth = 6, 
                         learning_rate = 0.1, colsample_bytree = 0.9, colsample_bylevel = 0.7,
                         objective = 'reg:squarederror')
xgb_model.fit(X_train, y_train)
# Out:
# XGBRegressor(colsample_bylevel=0.7, colsample_bytree=0.9, max_depth=6,
#              n_estimators=150, objective='reg:squarederror', subsample=0.8)

# %%
# Cross Validation Results

rmse = cross_val_score(xgb_model, X_train, y_train, scoring='neg_root_mean_squared_error', cv = kf)
r2 = cross_val_score(xgb_model, X_train, y_train, scoring='r2', cv = kf)

#get the mean of each fold 
print("RMSE: %.3f, Standard Deviation : %.3f" % (rmse.mean() * -1, rmse.std())) 
print("R2: %.3f, Standard Deviation : %.3f" % (r2.mean(), r2.std()))
# Out:
# RMSE: 1.809, Standard Deviation : 0.039
# R2: 0.785, Standard Deviation : 0.009

# %%
#Train/Test Results

xgb_y_train_predicted = xgb_model.predict(X_train)
xgb_y_test_predicted = xgb_model.predict(X_test)
calculate_errors(y_train, xgb_y_train_predicted, y_test, xgb_y_test_predicted, "XGBoost")
# Out:
# The R2 score of XGBoost is: 0.7796584110916321
# The RMSE of predicting the TRAINING set of XGBoost is: 1.0912924350901656
# The RMSE of predicting the TESTING set of XGBoost is: 1.8193871272116882
# The bias of predicting the TRAINING set of XGBoost is: -0.0027937810660117668
# The bias of predicting the TESTING set of XGBoost is: 0.022649010151427708

# %%
show_scatter_train(y_train, xgb_y_train_predicted, "XGBoost")

# %%
show_scatter_test(y_test, xgb_y_test_predicted, "XGBoost")

# %% [markdown]
# Residual Plots for XGBoost

# %%
sns.residplot(y_train, xgb_y_train_predicted)
plt.title('XGBoost Residual Plot: Training Data')

# %%
sns.residplot(y_test, xgb_y_test_predicted)
plt.title('XGBoost Residual Plot: Test Data')

# %% [markdown]
# ## Multi-Layer Neural Network

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.neural_network import MLPRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
mlp_X_train, mlp_X_test, mlp_y_train, mlp_y_test, mlp_scaler = get_train_test_split(df, 0.3, 2022, True)

# %%
mlp_model = MLPRegressor(learning_rate_init=0.01, batch_size=32, max_iter=200).fit(mlp_X_train, mlp_y_train)

# %%
mlp_model.predict(mlp_X_test)
# Out:
# array([3.46147348, 1.6097991 , 1.44052658, ..., 1.85523959, 9.40196642,
#        3.53664815])

# %%
mlp_model.score(mlp_X_test, mlp_y_test)
# Out:
# 0.6610244414491495

# %% [markdown]
# ### Evaluation of MLP Model

# %%
# Cross Validation Results

rmse = cross_val_score(mlp_model, mlp_X_train, mlp_y_train, scoring='neg_root_mean_squared_error')
r2 = cross_val_score(mlp_model, mlp_X_train, mlp_y_train, scoring='r2')

#get the mean of each fold 
print("RMSE: %.3f, Standard Deviation : %.3f" % (rmse.mean() * -1, rmse.std())) 
print("R2: %.3f, Standard Deviation : %.3f" % (r2.mean(), r2.std()))
# Out:
# RMSE: 2.106, Standard Deviation : 0.166
# R2: 0.720, Standard Deviation : 0.025

# %%
# Train/Test Results

mlp_y_train_predicted = mlp_model.predict(mlp_X_train)
mlp_y_test_predicted = mlp_model.predict(mlp_X_test)
calculate_errors(mlp_y_train, mlp_y_train_predicted, mlp_y_test, mlp_y_test_predicted, "MLP")
# Out:
# The R2 score of MLP is: 0.7050069799983378
# The RMSE of predicting the TRAINING set of MLP is: 2.086567669584828
# The RMSE of predicting the TESTING set of MLP is: 2.105148559199982
# The bias of predicting the TRAINING set of MLP is: 0.48967950422881934
# The bias of predicting the TESTING set of MLP is: 0.4822428991436537

# %%
show_scatter_train(mlp_y_train, mlp_y_train_predicted, "MLP")

# %%
show_scatter_test(mlp_y_test, mlp_y_test_predicted, "MLP")

# %% [markdown]
# Residual Plots for Multi-Layered Neural Network

# %%
sns.residplot(mlp_y_train, mlp_y_train_predicted)
plt.title('MLP Residual Plot: Training Data')
# Out:
# Text(0.5, 1.0, 'MLP Residual Plot: Training Data')

# %%
sns.residplot(mlp_y_test, mlp_y_test_predicted)
plt.title('MLP Residual Plot: Test Data')
# Out:
# Text(0.5, 1.0, 'MLP Residual Plot: Test Data')

# %% [markdown]
# ### LSTM

# %%
import numpy as np
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from tensorflow import keras
from tensorflow.keras import layers

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-dc2891961165> in <module>
# ----> 1 print(X_train.shape)
#       2 print(y_train.shape)
#
# NameError: name 'X_train' is not defined

# %%
#x = layers.Input(shape=(1, 41))
#cell = layers.SimpleRNNCell(4, activation='tanh')
#rnn = layers.RNN(cell)
#rnn_output = rnn(x)

# %%
#output = layers.Dense(units=1, activation='sigmoid')(rnn_output)
#model = keras.Model(inputs=x, outputs=output)
model = Sequential()
model.add(LSTM(4, input_shape=(41, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=2)
# Out:
# Epoch 1/100
# 10728/10728 - 61s - loss: 7.5552 - 61s/epoch - 6ms/step
# Epoch 2/100
# 10728/10728 - 61s - loss: 5.2664 - 61s/epoch - 6ms/step
# Epoch 3/100
# 10728/10728 - 59s - loss: 5.1365 - 59s/epoch - 6ms/step
# Epoch 4/100
# 10728/10728 - 61s - loss: 5.0007 - 61s/epoch - 6ms/step
# Epoch 5/100
# 10728/10728 - 60s - loss: 4.9279 - 60s/epoch - 6ms/step
# Epoch 6/100
# 10728/10728 - 59s - loss: 4.9096 - 59s/epoch - 6ms/step
# Epoch 7/100
# 10728/10728 - 61s - loss: 4.8732 - 61s/epoch - 6ms/step
# Epoch 8/100
# 10728/10728 - 59s - loss: 4.8522 - 59s/epoch - 6ms/step
# Epoch 9/100
# 10728/10728 - 59s - loss: 4.8300 - 59s/epoch - 6ms/step
# Epoch 10/100
# 10728/10728 - 61s - loss: 4.8042 - 61s/epoch - 6ms/step
# Epoch 11/100
# 10728/10728 - 59s - loss: 4.7871 - 59s/epoch - 6ms/step
# Epoch 12/100
# 10728/10728 - 61s - loss: 4.7694 - 61s/epoch - 6ms/step
# Epoch 13/100
# 10728/10728 - 59s - loss: 4.7441 - 59s/epoch - 6ms/step
# Epoch 14/100
# 10728/10728 - 59s - loss: 4.7271 - 59s/epoch - 6ms/step
# Epoch 15/100
# 10728/10728 - 60s - loss: 4.7052 - 60s/epoch - 6ms/step
# Epoch 16/100
# 10728/10728 - 59s - loss: 4.6891 - 59s/epoch - 6ms/step
# Epoch 17/100
# 10728/10728 - 61s - loss: 4.6863 - 61s/epoch - 6ms/step
# Epoch 18/100
# 10728/10728 - 59s - loss: 4.6884 - 59s/epoch - 6ms/step
# Epoch 19/100
# 10728/10728 - 59s - loss: 4.6738 - 59s/epoch - 5ms/step
# Epoch 20/100
# 10728/10728 - 60s - loss: 4.6755 - 60s/epoch - 6ms/step
# Epoch 21/100
# 10728/10728 - 59s - loss: 4.6675 - 59s/epoch - 5ms/step
# Epoch 22/100
# 10728/10728 - 59s - loss: 4.6349 - 59s/epoch - 5ms/step
# Epoch 23/100
# 10728/10728 - 60s - loss: 4.6471 - 60s/epoch - 6ms/step
# Epoch 24/100
# 10728/10728 - 59s - loss: 4.6274 - 59s/epoch - 5ms/step
# Epoch 25/100
# 10728/10728 - 69s - loss: 4.6261 - 69s/epoch - 6ms/step
# Epoch 26/100
# 10728/10728 - 59s - loss: 4.6252 - 59s/epoch - 5ms/step
# Epoch 27/100
# 10728/10728 - 59s - loss: 4.5779 - 59s/epoch - 5ms/step
# Epoch 28/100
# 10728/10728 - 60s - loss: 4.5970 - 60s/epoch - 6ms/step
# Epoch 29/100
# 10728/10728 - 59s - loss: 4.6014 - 59s/epoch - 6ms/step
# Epoch 30/100

# %%
# make predictions
trainPredict = model.predict(X_train)
testPredict = model.predict(X_test)
print(X_train.shape)
print(trainPredict.shape)

# %%
# invert predictions
trainPredict = scaler.inverse_transform(trainPredict)
y_train = scaler.inverse_transform([y_train])
testPredict = scaler.inverse_transform(testPredict)
y_test = scaler.inverse_transform([y_test])

# %%
# calculate root mean squared error
trainScore = np.sqrt(mean_squared_error(y_train[0], trainPredict[:,0]))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(y_test[0], testPredict[:,0]))
print('Test Score: %.2f RMSE' % (testScore))

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# %%
# shift test predictions for plotting
testPredictPlot = np.empty_like(df)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(df)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %% [markdown]
# ## LSTM Time series

# %%
#modeling
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from pandas import DataFrame , concat
from sklearn.metrics import mean_absolute_error , mean_squared_error
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
from numpy import mean , concatenate
from math import sqrt
from pandas import read_csv
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,LSTM,Activation
from numpy import array , hstack
from tensorflow import keras
import tensorflow as tf
# if you're using google drive to store the dataset
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = '/content/drive/MyDrive/Discovery_2022fall_photosynthesis_mapping/Data/' + \
 'train/data_monthly_v1_0.csv'
df = pd.read_csv(data_path)

# %%
# attributes of eddy covariance site
site_data_attrs = ['SITE_ID','dataset','LOCATION_LAT','LOCATION_LONG','SITE_IGBP','MODIS_PFT','koppen']

# target variable: GPP
target = 'GPP_NT_VUT_REF'

# %%
# explanatory variables
exp_vars = [
    'BESS-PAR',  
    'BESS-PARdiff', 
    'BESS-RSDN', 
    'Tmean', 
    'prcp', 
    'vpd', 
    'prcp-lag3',
    'ESACCI-sm', 
    'ET', 
    'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI', 'NIRv', 'kNDVI', 
    'CSIF-SIFdaily', 
    'Fpar', 'Lai', 
    'LST_Day', 'LST_Night', 
    'MODIS_PFT', 
    'koppen', 
]

# %%
# keep columns needed for stratified KFold
df_ohe = df[[target, 'MODIS_IGBP', 'SITE_ID'] + exp_vars]

categorical_columns = ['MODIS_PFT', 'koppen']
for col in categorical_columns:
    col_ohe = pd.get_dummies(df[col], prefix=col)
    df_ohe = pd.concat((df_ohe, col_ohe), axis=1).drop(col, axis=1)

df_ohe.columns
# Out:
# Index(['GPP_NT_VUT_REF', 'MODIS_IGBP', 'SITE_ID', 'BESS-PAR', 'BESS-PARdiff',
#        'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
#        'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
#        'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
#        'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
#        'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
#        'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
#        'koppen_Temperate', 'koppen_Tropical'],
#       dtype='object')

# %%
def clean_dataset(df):
    assert isinstance(df, pd.DataFrame), "df needs to be a pd.DataFrame"
    df.dropna(inplace=True)
    return df

# %%
df = clean_dataset(df_ohe)

# %%
# split the dataset into training and testing
Data = df[['BESS-PAR', 'BESS-PARdiff', 'SITE_ID',
       'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
       'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
       'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
       'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
       'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
       'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
       'koppen_Temperate', 'koppen_Tropical', target]]

# %%
import binascii
def test_set_check(identifier, test_ratio):
    return binascii.crc32(np.int64(hash(identifier))) & 0xffffffff < test_ratio * 2**32

# Function to split train/test
def split_train_test_by_id(data, test_ratio, id_column):
    ids = data[id_column]
    print(ids)
    in_test_set = ids.apply(lambda id_: test_set_check(id_, test_ratio))
    return data.loc[~in_test_set], data.loc[in_test_set]

# %%
test, train = split_train_test_by_id(Data, 0.7, "SITE_ID")
print(train.shape, test.shape)
# Out:
# 0        AR-SLu
# 1        AR-SLu
# 2        AR-SLu
# 3        AR-SLu
# 4        AR-SLu
#           ...
# 19008    SE-Lnn
# 19009    SE-Lnn
# 19010    SE-Lnn
# 19011    SE-Lnn
# 19012    SE-Lnn
# Name: SITE_ID, Length: 15327, dtype: object
# (11325, 43) (4002, 43)

# %%
train = train[['BESS-PAR', 'BESS-PARdiff',
       'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
       'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
       'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
       'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
       'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
       'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
       'koppen_Temperate', 'koppen_Tropical', target]]

test = test[['BESS-PAR', 'BESS-PARdiff',
       'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
       'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
       'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
       'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
       'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
       'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
       'koppen_Temperate', 'koppen_Tropical', target]]
data = Data[['BESS-PAR', 'BESS-PARdiff',
       'BESS-RSDN', 'Tmean', 'prcp', 'vpd', 'prcp-lag3', 'ESACCI-sm', 'ET',
       'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7', 'EVI', 'NDVI', 'GCI', 'NDWI',
       'NIRv', 'kNDVI', 'CSIF-SIFdaily', 'Fpar', 'Lai', 'LST_Day', 'LST_Night',
       'MODIS_PFT_CRO', 'MODIS_PFT_DBF', 'MODIS_PFT_EBF', 'MODIS_PFT_ENF',
       'MODIS_PFT_GRA', 'MODIS_PFT_MF', 'MODIS_PFT_Other', 'MODIS_PFT_SA',
       'MODIS_PFT_SH', 'koppen_Arid', 'koppen_Cold', 'koppen_Polar',
       'koppen_Temperate', 'koppen_Tropical', target]]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
data = np.vstack((train, test))
data_scaled = scaler.fit_transform(data)
train_scaled = data_scaled[:11116,]
test_scaled = data_scaled[11116:,]

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps_in, n_steps_out):
 X, y = list(), list()
 for i in range(len(sequences)):
  # find the end of this pattern
  end_ix = i + n_steps_in
  out_end_ix = end_ix + n_steps_out-1
  # check if we are beyond the dataset
  if out_end_ix > len(sequences):
   break
  # gather input and output parts of the pattern
  seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
  X.append(seq_x)
  y.append(seq_y)
 return array(X), array(y)



# choose a number of time steps #change this accordingly
n_steps_in, n_steps_out = 12 , 12
# covert into input/output
train_X, train_y = split_sequences(train_scaled, n_steps_in, n_steps_out)
test_X, test_y = split_sequences(test_scaled, n_steps_in, n_steps_out)

print ("train_X.shape" , train_X.shape) 
print ("train_y.shape" , train_y.shape)
print ("test_X.shape" , test_X.shape) 
print ("test_y.shape" , test_y.shape)
# Out:
# train_X.shape (11094, 12, 41)
# train_y.shape (11094, 12)
# test_X.shape (4189, 12, 41)
# test_y.shape (4189, 12)

# %%
#optimizer learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps_in, 41)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(n_steps_out))
model.add(Activation('linear'))
model.compile(loss='mse' , optimizer=opt , metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 12, 50)            18400
#
#  lstm_3 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 12)                612
#
#  activation_1 (Activation)   (None, 12)                0
#
# =================================================================
# Total params: 39,212
# Trainable params: 39,212
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=1, verbose=2)
history
# Out:
# Epoch 1/100
# 11094/11094 - 78s - loss: 0.0209 - mse: 0.0209 - 78s/epoch - 7ms/step
# Epoch 2/100
# 11094/11094 - 70s - loss: 0.0169 - mse: 0.0169 - 70s/epoch - 6ms/step
# Epoch 3/100
# 11094/11094 - 70s - loss: 0.0160 - mse: 0.0160 - 70s/epoch - 6ms/step
# Epoch 4/100
# 11094/11094 - 70s - loss: 0.0154 - mse: 0.0154 - 70s/epoch - 6ms/step
# Epoch 5/100
# 11094/11094 - 74s - loss: 0.0149 - mse: 0.0149 - 74s/epoch - 7ms/step
# Epoch 6/100
# 11094/11094 - 69s - loss: 0.0144 - mse: 0.0144 - 69s/epoch - 6ms/step
# Epoch 7/100
# 11094/11094 - 72s - loss: 0.0140 - mse: 0.0140 - 72s/epoch - 7ms/step
# Epoch 8/100
# 11094/11094 - 69s - loss: 0.0138 - mse: 0.0138 - 69s/epoch - 6ms/step
# Epoch 9/100
# 11094/11094 - 72s - loss: 0.0135 - mse: 0.0135 - 72s/epoch - 7ms/step
# Epoch 10/100
# 11094/11094 - 69s - loss: 0.0133 - mse: 0.0133 - 69s/epoch - 6ms/step
# Epoch 11/100
# 11094/11094 - 69s - loss: 0.0131 - mse: 0.0131 - 69s/epoch - 6ms/step
# Epoch 12/100
# 11094/11094 - 70s - loss: 0.0130 - mse: 0.0130 - 70s/epoch - 6ms/step
# Epoch 13/100
# 11094/11094 - 73s - loss: 0.0128 - mse: 0.0128 - 73s/epoch - 7ms/step
# Epoch 14/100
# 11094/11094 - 68s - loss: 0.0127 - mse: 0.0127 - 68s/epoch - 6ms/step
# Epoch 15/100
# 11094/11094 - 68s - loss: 0.0126 - mse: 0.0126 - 68s/epoch - 6ms/step
# Epoch 16/100
# 11094/11094 - 68s - loss: 0.0124 - mse: 0.0124 - 68s/epoch - 6ms/step
# Epoch 17/100
# 11094/11094 - 72s - loss: 0.0123 - mse: 0.0123 - 72s/epoch - 6ms/step
# Epoch 18/100
# 11094/11094 - 70s - loss: 0.0122 - mse: 0.0122 - 70s/epoch - 6ms/step
# Epoch 19/100
# 11094/11094 - 70s - loss: 0.0121 - mse: 0.0121 - 70s/epoch - 6ms/step
# Epoch 20/100
# 11094/11094 - 69s - loss: 0.0120 - mse: 0.0120 - 69s/epoch - 6ms/step
# Epoch 21/100
# 11094/11094 - 74s - loss: 0.0119 - mse: 0.0119 - 74s/epoch - 7ms/step
# Epoch 22/100
# 11094/11094 - 71s - loss: 0.0118 - mse: 0.0118 - 71s/epoch - 6ms/step
# Epoch 23/100
# 11094/11094 - 70s - loss: 0.0117 - mse: 0.0117 - 70s/epoch - 6ms/step
# Epoch 24/100
# 11094/11094 - 69s - loss: 0.0117 - mse: 0.0117 - 69s/epoch - 6ms/step
# Epoch 25/100
# 11094/11094 - 72s - loss: 0.0116 - mse: 0.0116 - 72s/epoch - 7ms/step
# Epoch 26/100
# 11094/11094 - 68s - loss: 0.0115 - mse: 0.0115 - 68s/epoch - 6ms/step
# Epoch 27/100
# 11094/11094 - 68s - loss: 0.0114 - mse: 0.0114 - 68s/epoch - 6ms/step
# Epoch 28/100
# 11094/11094 - 69s - loss: 0.0113 - mse: 0.0113 - 69s/epoch - 6ms/step
# Epoch 29/100
# 11094/11094 - 73s - loss: 0.0112 - mse: 0.0112 - 73s/epoch - 7ms/step
# Epoch 30/100
# 11094/11094 - 69s - loss: 0.0112 - mse: 0.0112 - 69s/epoch - 6ms/step
# Epoch 31/100
# 11094/11094 - 69s - loss: 0.0111 - mse: 0.0111 - 69s/epoch - 6ms/step
# Epoch 32/100
# 11094/11094 - 69s - loss: 0.0110 - mse: 0.0110 - 69s/epoch - 6ms/step
# Epoch 33/100
# 11094/11094 - 74s - loss: 0.0109 - mse: 0.0109 - 74s/epoch - 7ms/step
# Epoch 34/100
# 11094/11094 - 70s - loss: 0.0108 - mse: 0.0108 - 70s/epoch - 6ms/step
# Epoch 35/100
# 11094/11094 - 71s - loss: 0.0108 - mse: 0.0108 - 71s/epoch - 6ms/step
# Epoch 36/100
# 11094/11094 - 70s - loss: 0.0107 - mse: 0.0107 - 70s/epoch - 6ms/step
# Epoch 37/100
# 11094/11094 - 76s - loss: 0.0106 - mse: 0.0106 - 76s/epoch - 7ms/step
# Epoch 38/100
# 11094/11094 - 70s - loss: 0.0105 - mse: 0.0105 - 70s/epoch - 6ms/step
# Epoch 39/100
# 11094/11094 - 70s - loss: 0.0105 - mse: 0.0105 - 70s/epoch - 6ms/step
# Epoch 40/100
# 11094/11094 - 68s - loss: 0.0104 - mse: 0.0104 - 68s/epoch - 6ms/step
# Epoch 41/100
# 11094/11094 - 75s - loss: 0.0103 - mse: 0.0103 - 75s/epoch - 7ms/step
# Epoch 42/100
# 11094/11094 - 73s - loss: 0.0102 - mse: 0.0102 - 73s/epoch - 7ms/step
# Epoch 43/100
# 11094/11094 - 80s - loss: 0.0102 - mse: 0.0102 - 80s/epoch - 7ms/step
# Epoch 44/100
# 11094/11094 - 80s - loss: 0.0101 - mse: 0.0101 - 80s/epoch - 7ms/step
# Epoch 45/100
# 11094/11094 - 82s - loss: 0.0101 - mse: 0.0101 - 82s/epoch - 7ms/step
# Epoch 46/100
# 11094/11094 - 81s - loss: 0.0100 - mse: 0.0100 - 81s/epoch - 7ms/step
# Epoch 47/100
# 11094/11094 - 73s - loss: 0.0099 - mse: 0.0099 - 73s/epoch - 7ms/step
# Epoch 48/100
# 11094/11094 - 77s - loss: 0.0098 - mse: 0.0098 - 77s/epoch - 7ms/step
# Epoch 49/100
# 11094/11094 - 71s - loss: 0.0098 - mse: 0.0098 - 71s/epoch - 6ms/step
# Epoch 50/100
# 11094/11094 - 70s - loss: 0.0097 - mse: 0.0097 - 70s/epoch - 6ms/step
# Epoch 51/100
# 11094/11094 - 70s - loss: 0.0096 - mse: 0.0096 - 70s/epoch - 6ms/step
# Epoch 52/100
# 11094/11094 - 74s - loss: 0.0096 - mse: 0.0096 - 74s/epoch - 7ms/step
# Epoch 53/100
# 11094/11094 - 70s - loss: 0.0095 - mse: 0.0095 - 70s/epoch - 6ms/step
# Epoch 54/100
# 11094/11094 - 69s - loss: 0.0094 - mse: 0.0094 - 69s/epoch - 6ms/step
# Epoch 55/100
# 11094/11094 - 69s - loss: 0.0094 - mse: 0.0094 - 69s/epoch - 6ms/step
# Epoch 56/100
# 11094/11094 - 74s - loss: 0.0093 - mse: 0.0093 - 74s/epoch - 7ms/step
# Epoch 57/100
# 11094/11094 - 70s - loss: 0.0092 - mse: 0.0092 - 70s/epoch - 6ms/step
# Epoch 58/100
# 11094/11094 - 69s - loss: 0.0092 - mse: 0.0092 - 69s/epoch - 6ms/step
# Epoch 59/100
# 11094/11094 - 70s - loss: 0.0091 - mse: 0.0091 - 70s/epoch - 6ms/step
# Epoch 60/100
# 11094/11094 - 74s - loss: 0.0091 - mse: 0.0091 - 74s/epoch - 7ms/step
# Epoch 61/100
# 11094/11094 - 70s - loss: 0.0090 - mse: 0.0090 - 70s/epoch - 6ms/step
# Epoch 62/100
# 11094/11094 - 70s - loss: 0.0089 - mse: 0.0089 - 70s/epoch - 6ms/step
# Epoch 63/100
# 11094/11094 - 70s - loss: 0.0089 - mse: 0.0089 - 70s/epoch - 6ms/step
# Epoch 64/100
# 11094/11094 - 75s - loss: 0.0088 - mse: 0.0088 - 75s/epoch - 7ms/step
# Epoch 65/100
# 11094/11094 - 75s - loss: 0.0088 - mse: 0.0088 - 75s/epoch - 7ms/step
# Epoch 66/100
# 11094/11094 - 75s - loss: 0.0087 - mse: 0.0087 - 75s/epoch - 7ms/step
# Epoch 67/100
# 11094/11094 - 75s - loss: 0.0086 - mse: 0.0086 - 75s/epoch - 7ms/step
# Epoch 68/100
# 11094/11094 - 80s - loss: 0.0086 - mse: 0.0086 - 80s/epoch - 7ms/step
# Epoch 69/100
# 11094/11094 - 76s - loss: 0.0085 - mse: 0.0085 - 76s/epoch - 7ms/step
# Epoch 70/100
# 11094/11094 - 76s - loss: 0.0084 - mse: 0.0084 - 76s/epoch - 7ms/step
# Epoch 71/100
# 11094/11094 - 83s - loss: 0.0084 - mse: 0.0084 - 83s/epoch - 7ms/step
# Epoch 72/100
# 11094/11094 - 83s - loss: 0.0083 - mse: 0.0083 - 83s/epoch - 7ms/step
# Epoch 73/100
# 11094/11094 - 76s - loss: 0.0083 - mse: 0.0083 - 76s/epoch - 7ms/step
# Epoch 74/100
# 11094/11094 - 76s - loss: 0.0082 - mse: 0.0082 - 76s/epoch - 7ms/step
# Epoch 75/100
# 11094/11094 - 80s - loss: 0.0082 - mse: 0.0082 - 80s/epoch - 7ms/step
# Epoch 76/100
# 11094/11094 - 76s - loss: 0.0081 - mse: 0.0081 - 76s/epoch - 7ms/step
# Epoch 77/100
# 11094/11094 - 75s - loss: 0.0081 - mse: 0.0081 - 75s/epoch - 7ms/step
# Epoch 78/100
# 11094/11094 - 71s - loss: 0.0080 - mse: 0.0080 - 71s/epoch - 6ms/step
# Epoch 79/100
# 11094/11094 - 75s - loss: 0.0079 - mse: 0.0079 - 75s/epoch - 7ms/step
# Epoch 80/100
# 11094/11094 - 70s - loss: 0.0079 - mse: 0.0079 - 70s/epoch - 6ms/step
# Epoch 81/100
# 11094/11094 - 70s - loss: 0.0078 - mse: 0.0078 - 70s/epoch - 6ms/step
# Epoch 82/100
# 11094/11094 - 71s - loss: 0.0078 - mse: 0.0078 - 71s/epoch - 6ms/step
# Epoch 83/100
# 11094/11094 - 74s - loss: 0.0077 - mse: 0.0077 - 74s/epoch - 7ms/step
# Epoch 84/100
# 11094/11094 - 71s - loss: 0.0077 - mse: 0.0077 - 71s/epoch - 6ms/step
# Epoch 85/100
# 11094/11094 - 71s - loss: 0.0076 - mse: 0.0076 - 71s/epoch - 6ms/step
# Epoch 86/100
# 11094/11094 - 71s - loss: 0.0076 - mse: 0.0076 - 71s/epoch - 6ms/step
# Epoch 87/100
# 11094/11094 - 74s - loss: 0.0075 - mse: 0.0075 - 74s/epoch - 7ms/step
# Epoch 88/100
# 11094/11094 - 72s - loss: 0.0075 - mse: 0.0075 - 72s/epoch - 6ms/step
# Epoch 89/100
# 11094/11094 - 71s - loss: 0.0074 - mse: 0.0074 - 71s/epoch - 6ms/step
# Epoch 90/100
# 11094/11094 - 69s - loss: 0.0074 - mse: 0.0074 - 69s/epoch - 6ms/step
# Epoch 91/100
# 11094/11094 - 73s - loss: 0.0074 - mse: 0.0074 - 73s/epoch - 7ms/step
# Epoch 92/100
# 11094/11094 - 70s - loss: 0.0073 - mse: 0.0073 - 70s/epoch - 6ms/step
# Epoch 93/100
# 11094/11094 - 70s - loss: 0.0073 - mse: 0.0073 - 70s/epoch - 6ms/step
# Epoch 94/100
# 11094/11094 - 70s - loss: 0.0072 - mse: 0.0072 - 70s/epoch - 6ms/step
# Epoch 95/100
# 11094/11094 - 73s - loss: 0.0072 - mse: 0.0072 - 73s/epoch - 7ms/step
# Epoch 96/100
# 11094/11094 - 69s - loss: 0.0071 - mse: 0.0071 - 69s/epoch - 6ms/step
# Epoch 97/100
# 11094/11094 - 69s - loss: 0.0070 - mse: 0.0070 - 69s/epoch - 6ms/step
# Epoch 98/100
# 11094/11094 - 69s - loss: 0.0070 - mse: 0.0070 - 69s/epoch - 6ms/step
# Epoch 99/100
# 11094/11094 - 73s - loss: 0.0070 - mse: 0.0070 - 73s/epoch - 7ms/step
# Epoch 100/100
# 11094/11094 - 68s - loss: 0.0069 - mse: 0.0069 - 68s/epoch - 6ms/step

# %%
trainPredict = model.predict(train_X)
testPredict = model.predict(test_X)
# Out:
# 347/347 [==============================] - 2s 5ms/step
# 131/131 [==============================] - 1s 5ms/step

# %%
trainScore = np.sqrt(mean_squared_error(train_y, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(test_y, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 0.08 RMSE
# Test Score: 0.14 RMSE

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mse'])

# %%
# Model Training History

plt.figure(figsize=(10,10))


# history for mse  
   
plt.subplot(211)  
plt.plot(history.history['mse'])  
plt.title('model mse')  
plt.ylabel('mse')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
   
# history for loss  
   
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
plt.show()

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=1, verbose=2, validation_data=(test_X, test_y))
history
# Out:
# Epoch 1/100
# 11094/11094 - 83s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0207 - val_mse: 0.0207 - 83s/epoch - 7ms/step
# Epoch 2/100
# 11094/11094 - 82s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0210 - val_mse: 0.0210 - 82s/epoch - 7ms/step
# Epoch 3/100
# 11094/11094 - 81s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0209 - val_mse: 0.0209 - 81s/epoch - 7ms/step
# Epoch 4/100
# 11094/11094 - 79s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0227 - val_mse: 0.0227 - 79s/epoch - 7ms/step
# Epoch 5/100
# 11094/11094 - 84s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0217 - val_mse: 0.0217 - 84s/epoch - 8ms/step
# Epoch 6/100
# 11094/11094 - 81s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0208 - val_mse: 0.0208 - 81s/epoch - 7ms/step
# Epoch 7/100
# 11094/11094 - 79s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0216 - val_mse: 0.0216 - 79s/epoch - 7ms/step
# Epoch 8/100
# 11094/11094 - 80s - loss: 0.0060 - mse: 0.0060 - val_loss: 0.0217 - val_mse: 0.0217 - 80s/epoch - 7ms/step
# Epoch 9/100
# 11094/11094 - 84s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0211 - val_mse: 0.0211 - 84s/epoch - 8ms/step
# Epoch 10/100
# 11094/11094 - 79s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0213 - val_mse: 0.0213 - 79s/epoch - 7ms/step
# Epoch 11/100
# 11094/11094 - 80s - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0222 - val_mse: 0.0222 - 80s/epoch - 7ms/step
# Epoch 12/100
# 11094/11094 - 79s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0210 - val_mse: 0.0210 - 79s/epoch - 7ms/step
# Epoch 13/100
# 11094/11094 - 85s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0222 - val_mse: 0.0222 - 85s/epoch - 8ms/step
# Epoch 14/100
# 11094/11094 - 79s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0215 - val_mse: 0.0215 - 79s/epoch - 7ms/step
# Epoch 15/100
# 11094/11094 - 80s - loss: 0.0058 - mse: 0.0058 - val_loss: 0.0228 - val_mse: 0.0228 - 80s/epoch - 7ms/step
# Epoch 16/100
# 11094/11094 - 84s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0238 - val_mse: 0.0238 - 84s/epoch - 8ms/step
# Epoch 17/100
# 11094/11094 - 79s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0221 - val_mse: 0.0221 - 79s/epoch - 7ms/step
# Epoch 18/100
# 11094/11094 - 81s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0211 - val_mse: 0.0211 - 81s/epoch - 7ms/step
# Epoch 19/100
# 11094/11094 - 81s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0206 - val_mse: 0.0206 - 81s/epoch - 7ms/step
# Epoch 20/100
# 11094/11094 - 80s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0231 - val_mse: 0.0231 - 80s/epoch - 7ms/step
# Epoch 21/100
# 11094/11094 - 83s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0217 - val_mse: 0.0217 - 83s/epoch - 7ms/step
# Epoch 22/100
# 11094/11094 - 82s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0215 - val_mse: 0.0215 - 82s/epoch - 7ms/step
# Epoch 23/100
# 11094/11094 - 82s - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0214 - val_mse: 0.0214 - 82s/epoch - 7ms/step
# Epoch 24/100
# 11094/11094 - 80s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0227 - val_mse: 0.0227 - 80s/epoch - 7ms/step
# Epoch 25/100
# 11094/11094 - 82s - loss: 0.0055 - mse: 0.0055 - val_loss: 0.0229 - val_mse: 0.0229 - 82s/epoch - 7ms/step
# Epoch 26/100
# 11094/11094 - 80s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0231 - val_mse: 0.0231 - 80s/epoch - 7ms/step
# Epoch 27/100
# 11094/11094 - 82s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0214 - val_mse: 0.0214 - 82s/epoch - 7ms/step
# Epoch 28/100
# 11094/11094 - 79s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0218 - val_mse: 0.0218 - 79s/epoch - 7ms/step
# Epoch 29/100
# 11094/11094 - 79s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0216 - val_mse: 0.0216 - 79s/epoch - 7ms/step
# Epoch 30/100
# 11094/11094 - 85s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0220 - val_mse: 0.0220 - 85s/epoch - 8ms/step
# Epoch 31/100
# 11094/11094 - 86s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0219 - val_mse: 0.0219 - 86s/epoch - 8ms/step
# Epoch 32/100
# 11094/11094 - 89s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0224 - val_mse: 0.0224 - 89s/epoch - 8ms/step
# Epoch 33/100
# 11094/11094 - 91s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0221 - val_mse: 0.0221 - 91s/epoch - 8ms/step
# Epoch 34/100
# 11094/11094 - 89s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0220 - val_mse: 0.0220 - 89s/epoch - 8ms/step
# Epoch 35/100
# 11094/11094 - 92s - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0226 - val_mse: 0.0226 - 92s/epoch - 8ms/step
# Epoch 36/100
# 11094/11094 - 92s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0226 - val_mse: 0.0226 - 92s/epoch - 8ms/step
# Epoch 37/100
# 11094/11094 - 87s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0217 - val_mse: 0.0217 - 87s/epoch - 8ms/step
# Epoch 38/100
# 11094/11094 - 89s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0214 - val_mse: 0.0214 - 89s/epoch - 8ms/step
# Epoch 39/100
# 11094/11094 - 84s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0228 - val_mse: 0.0228 - 84s/epoch - 8ms/step
# Epoch 40/100
# 11094/11094 - 85s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0220 - val_mse: 0.0220 - 85s/epoch - 8ms/step
# Epoch 41/100
# 11094/11094 - 84s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0224 - val_mse: 0.0224 - 84s/epoch - 8ms/step
# Epoch 42/100
# 11094/11094 - 82s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0228 - val_mse: 0.0228 - 82s/epoch - 7ms/step
# Epoch 43/100
# 11094/11094 - 94s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0221 - val_mse: 0.0221 - 94s/epoch - 8ms/step
# Epoch 44/100
# 11094/11094 - 82s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0218 - val_mse: 0.0218 - 82s/epoch - 7ms/step
# Epoch 45/100
# 11094/11094 - 83s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0238 - val_mse: 0.0238 - 83s/epoch - 7ms/step
# Epoch 46/100
# 11094/11094 - 83s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0226 - val_mse: 0.0226 - 83s/epoch - 8ms/step
# Epoch 47/100
# 11094/11094 - 92s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0216 - val_mse: 0.0216 - 92s/epoch - 8ms/step
# Epoch 48/100
# 11094/11094 - 84s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0223 - val_mse: 0.0223 - 84s/epoch - 8ms/step
# Epoch 49/100
# 11094/11094 - 83s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0228 - val_mse: 0.0228 - 83s/epoch - 8ms/step
# Epoch 50/100
# 11094/11094 - 85s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0221 - val_mse: 0.0221 - 85s/epoch - 8ms/step
# Epoch 51/100
# 11094/11094 - 85s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0228 - val_mse: 0.0228 - 85s/epoch - 8ms/step
# Epoch 52/100
# 11094/11094 - 81s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0215 - val_mse: 0.0215 - 81s/epoch - 7ms/step
# Epoch 53/100
# 11094/11094 - 85s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0240 - val_mse: 0.0240 - 85s/epoch - 8ms/step
# Epoch 54/100
# 11094/11094 - 81s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0225 - val_mse: 0.0225 - 81s/epoch - 7ms/step
# Epoch 55/100
# 11094/11094 - 85s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0227 - val_mse: 0.0227 - 85s/epoch - 8ms/step
# Epoch 56/100
# 11094/11094 - 85s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0231 - val_mse: 0.0231 - 85s/epoch - 8ms/step
# Epoch 57/100
# 11094/11094 - 83s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0227 - val_mse: 0.0227 - 83s/epoch - 8ms/step
# Epoch 58/100
# 11094/11094 - 81s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0233 - val_mse: 0.0233 - 81s/epoch - 7ms/step
# Epoch 59/100
# 11094/11094 - 87s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0234 - val_mse: 0.0234 - 87s/epoch - 8ms/step
# Epoch 60/100
# 11094/11094 - 80s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0237 - val_mse: 0.0237 - 80s/epoch - 7ms/step
# Epoch 61/100
# 11094/11094 - 84s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0237 - val_mse: 0.0237 - 84s/epoch - 8ms/step
# Epoch 62/100
# 11094/11094 - 82s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0244 - val_mse: 0.0244 - 82s/epoch - 7ms/step
# Epoch 63/100
# 11094/11094 - 83s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0243 - val_mse: 0.0243 - 83s/epoch - 7ms/step
# Epoch 64/100
# 11094/11094 - 83s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0239 - val_mse: 0.0239 - 83s/epoch - 8ms/step
# Epoch 65/100
# 11094/11094 - 91s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0234 - val_mse: 0.0234 - 91s/epoch - 8ms/step
# Epoch 66/100
# 11094/11094 - 83s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0239 - val_mse: 0.0239 - 83s/epoch - 7ms/step
# Epoch 67/100
# 11094/11094 - 83s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0222 - val_mse: 0.0222 - 83s/epoch - 7ms/step
# Epoch 68/100
# 11094/11094 - 82s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0236 - val_mse: 0.0236 - 82s/epoch - 7ms/step
# Epoch 69/100
# 11094/11094 - 85s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0239 - val_mse: 0.0239 - 85s/epoch - 8ms/step
# Epoch 70/100
# 11094/11094 - 82s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0242 - val_mse: 0.0242 - 82s/epoch - 7ms/step
# Epoch 71/100
# 11094/11094 - 82s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0240 - val_mse: 0.0240 - 82s/epoch - 7ms/step
# Epoch 72/100
# 11094/11094 - 86s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0227 - val_mse: 0.0227 - 86s/epoch - 8ms/step
# Epoch 73/100
# 11094/11094 - 82s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0232 - val_mse: 0.0232 - 82s/epoch - 7ms/step
# Epoch 74/100
# 11094/11094 - 83s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0240 - val_mse: 0.0240 - 83s/epoch - 7ms/step
# Epoch 75/100
# 11094/11094 - 84s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0242 - val_mse: 0.0242 - 84s/epoch - 8ms/step
# Epoch 76/100
# 11094/11094 - 83s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0232 - val_mse: 0.0232 - 83s/epoch - 7ms/step
# Epoch 77/100
# 11094/11094 - 84s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0235 - val_mse: 0.0235 - 84s/epoch - 8ms/step
# Epoch 78/100
# 11094/11094 - 92s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0233 - val_mse: 0.0233 - 92s/epoch - 8ms/step
# Epoch 79/100
# 11094/11094 - 82s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0232 - val_mse: 0.0232 - 82s/epoch - 7ms/step
# Epoch 80/100
# 11094/11094 - 87s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0238 - val_mse: 0.0238 - 87s/epoch - 8ms/step
# Epoch 81/100
# 11094/11094 - 82s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0237 - val_mse: 0.0237 - 82s/epoch - 7ms/step
# Epoch 82/100
# 11094/11094 - 83s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0236 - val_mse: 0.0236 - 83s/epoch - 7ms/step
# Epoch 83/100
# 11094/11094 - 84s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0235 - val_mse: 0.0235 - 84s/epoch - 8ms/step
# Epoch 84/100
# 11094/11094 - 81s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0238 - val_mse: 0.0238 - 81s/epoch - 7ms/step
# Epoch 85/100
# 11094/11094 - 86s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0233 - val_mse: 0.0233 - 86s/epoch - 8ms/step
# Epoch 86/100
# 11094/11094 - 82s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0240 - val_mse: 0.0240 - 82s/epoch - 7ms/step
# Epoch 87/100
# 11094/11094 - 84s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0243 - val_mse: 0.0243 - 84s/epoch - 8ms/step
# Epoch 88/100
# 11094/11094 - 82s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0241 - val_mse: 0.0241 - 82s/epoch - 7ms/step
# Epoch 89/100
# 11094/11094 - 84s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0242 - val_mse: 0.0242 - 84s/epoch - 8ms/step
# Epoch 90/100
# 11094/11094 - 79s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0251 - val_mse: 0.0251 - 79s/epoch - 7ms/step
# Epoch 91/100
# 11094/11094 - 82s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0246 - val_mse: 0.0246 - 82s/epoch - 7ms/step
# Epoch 92/100
# 11094/11094 - 81s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0249 - val_mse: 0.0249 - 81s/epoch - 7ms/step
# Epoch 93/100
# 11094/11094 - 80s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0260 - val_mse: 0.0260 - 80s/epoch - 7ms/step
# Epoch 94/100
# 11094/11094 - 84s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0249 - val_mse: 0.0249 - 84s/epoch - 8ms/step
# Epoch 95/100
# 11094/11094 - 80s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0257 - val_mse: 0.0257 - 80s/epoch - 7ms/step
# Epoch 96/100
# 11094/11094 - 82s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0262 - val_mse: 0.0262 - 82s/epoch - 7ms/step
# Epoch 97/100
# 11094/11094 - 81s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0260 - val_mse: 0.0260 - 81s/epoch - 7ms/step
# Epoch 98/100
# 11094/11094 - 81s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0263 - val_mse: 0.0263 - 81s/epoch - 7ms/step
# Epoch 99/100
# 11094/11094 - 84s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0267 - val_mse: 0.0267 - 84s/epoch - 8ms/step
# Epoch 100/100
# 11094/11094 - 80s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0263 - val_mse: 0.0263 - 80s/epoch - 7ms/step

# %%
# Model Training History

plt.figure(figsize=(10,10))


# history for mse  
   
plt.subplot(211)  
plt.plot(history.history['mse'])
plt.plot(history.history['val_mse'])    
plt.title('model mse')  
plt.ylabel('mse')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
   
# history for loss  
   
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('model loss')  
plt.ylabel('loss')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')  
plt.show()

# %%
#optimizer learning rate
opt = keras.optimizers.Adam(learning_rate=0.0001)
# define model
model_time = Sequential()
model_time.add(LSTM(50, activation='relu', return_sequences=True, input_shape=(n_steps_in, 41)))
model_time.add(LSTM(50, activation='relu'))
model_time.add(Dense(n_steps_out))
model_time.add(Activation('linear'))
model_time.compile(loss='mse' , optimizer=opt , metrics=['mse'])

# %%
history = model_time.fit(train_X , train_y , epochs=60 , steps_per_epoch=12 , verbose=1, shuffle=False)

# %%
trainPredict_time = model_time.predict(train_X)
testPredict_time = model_time.predict(test_X)

# %%
trainScore = np.sqrt(mean_squared_error(train_y, trainPredict_time))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = np.sqrt(mean_squared_error(test_y, testPredict_time))
print('Test Score: %.2f RMSE' % (testScore))
